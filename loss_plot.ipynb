# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pre_gen=np.load("pre_gen_loss.npy")
pre_dis=np.load("pre_dis_loss.npy")
gan_gen=np.load("gan_gen_loss.npy")
gan_dis=np.load("gan_dis_loss.npy")
print(pre_dis)
print(gan_dis)
# Out:
# [[0.61967747 0.58537776 0.56558639 0.53314715 0.50737138 0.4969538
#   0.49265244 0.49104148 0.49062344 0.48921026 0.48870976 0.48835878
#   0.48765024 0.48719448 0.4867163  0.48747291 0.48640252 0.48762552
#   0.48575356 0.48542025 0.48523202 0.48502984 0.48511997 0.48529757
#   0.48500519 0.48416504 0.48490036 0.48395079 0.48350557 0.48386624
#   0.48355137 0.48314346 0.48359261 0.48361715 0.48247583 0.48243299
#   0.48240139 0.48238078 0.48102719 0.48048602 0.48101065 0.48126762
#   0.480164   0.48066603 0.48065048 0.4802639  0.4803931  0.47917811
#   0.47912692 0.47929307]]
# [0.47759758 0.47697258 0.47722911 0.47709379 0.47708774 0.47713893
#  0.47715921 0.47710734 0.47682209 0.47705153 0.4769343  0.47679347
#  0.4768306  0.47693125 0.47693048 0.47680029 0.47682318 0.4767597
#  0.47686758 0.4767757  0.47655694 0.47663243 0.47666753 0.47672136
#  0.47651304 0.4766456  0.47685234 0.476656   0.4764546  0.47645147
#  0.47667743 0.4765487  0.47663862 0.4763008  0.47650913 0.47655237
# ...

# %%
dis_loss=np.concatenate((pre_dis,gan_dis.reshape(1,len(gan_dis))),axis=1)
gen_loss=np.concatenate((pre_gen,gan_gen.reshape(1,len(gan_gen))),axis=1)

# %%
plt.plot(dis_loss[0][50:],'r')
plt.show()

# %%
plt.plot(gen_loss[0][50:],'b')
plt.show()
